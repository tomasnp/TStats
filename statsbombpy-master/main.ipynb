# %%
from statsbombpy  import sb

# %%
sb.competitions()
# Out:
# /Users/thomassinapi/Desktop/statsbombpy-master/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# ...

# %%
sb.matches(competition_id=43, season_id=3)
# Out:
# /Users/thomassinapi/Desktop/statsbombpy-master/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#     match_id  match_date      kick_off                     competition season  \
# 0       7578  2018-06-15  14:00:00.000  International - FIFA World Cup   2018
# 1       7553  2018-06-23  17:00:00.000  International - FIFA World Cup   2018
# 2       7544  2018-06-20  17:00:00.000  International - FIFA World Cup   2018
# 3       7536  2018-06-18  17:00:00.000  International - FIFA World Cup   2018
# 4       7555  2018-06-24  20:00:00.000  International - FIFA World Cup   2018
# ..       ...         ...           ...                             ...    ...
# 59      7540  2018-06-19  20:00:00.000  International - FIFA World Cup   2018
# 60      8652  2018-07-07  20:00:00.000  International - FIFA World Cup   2018
# ...

# %%
sb.lineups(match_id=8652)
# Out:
# /Users/thomassinapi/Desktop/statsbombpy-master/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
# {'Croatia':     player_id       player_name player_nickname  jersey_number  country  \
#  0        3444   Danijel Subašić            None             23  Croatia
#  1        3471      Dejan Lovren            None              6  Croatia
#  2        5456     Mateo Kovačić            None              8  Croatia
#  3        5457      Ivan Strinić            None              3  Croatia
#  4        5460   Andrej Kramarić            None              9  Croatia
#  5        5461     Šime Vrsaljko            None              2  Croatia
#  6        5463       Luka Modrić            None             10  Croatia
#  7        5465        Ante Rebić            None             18  Croatia
#  8        5468      Domagoj Vida            None             21  Croatia
# ...

# %%
sb.events(match_id=8652)
# Out:
# /Users/thomassinapi/Desktop/statsbombpy-master/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#      50_50 bad_behaviour_card ball_receipt_outcome  \
# 0      NaN                NaN                  NaN
# 1      NaN                NaN                  NaN
# 2      NaN                NaN                  NaN
# 3      NaN                NaN                  NaN
# 4      NaN                NaN                  NaN
# ...    ...                ...                  ...
# 4043   NaN                NaN                  NaN
# 4044   NaN                NaN                  NaN
# 4045   NaN                NaN                  NaN
# 4046   NaN        Yellow Card                  NaN
# 4047   NaN                NaN                  NaN
#
#      ball_recovery_recovery_failure block_deflection block_offensive  \
# ...

# %%
events = sb.competition_events(
    country="Europe",
    division= "UEFA Euro",
    season="2020",
    gender="male"
)
events
# Out:
# /Users/thomassinapi/Desktop/statsbombpy-master/statsbombpy/api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)

# %%
player_match = sb.player_match_stats(3795506)
#player_season = sb.player_season_stats(competition_id=55, season_id=43)
#team_season = sb.team_season_stats(competition_id=55, season_id=43)

player_match
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-11-a5b26eafae5c> in <module>
# ----> 1 player_match = sb.player_match_stats(3795506)
#       2 #player_season = sb.player_season_stats(competition_id=55, season_id=43)
#       3 #team_season = sb.team_season_stats(competition_id=55, season_id=43)
#       4
#       5 player_match
#
# ~/Desktop/statsbombpy-master/statsbombpy/sb.py in player_match_stats(match_id, fmt, creds)
#     204         player_match_stats = api_client.player_match_stats(match_id, creds=creds)
#     205     else:
# --> 206         raise Exception(
#     207             "There is currently no open data for aggregated stats, please provide credentials"
#     208         )
#
# Exception: There is currently no open data for aggregated stats, please provide credentials

# %%
sb.competitions(fmt="dict")

sb.matches(competition_id=55, season_id=43, fmt="dict")

sb.lineups(match_id=3795506, fmt="dict")

sb.events(3795506, fmt="dict")


sb.frames(3795506, fmt="dict")


sb.player_match_stats(3795506, fmt="dict")

sb.player_season_stats(competition_id=55, season_id=43, fmt="dict")

sb.team_season_stats(competition_id=55, season_id=43, fmt="dict")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-e898400a255e> in <module>
#      11
#      12
# ---> 13 sb.player_match_stats(3795506, fmt="dict")
#      14
#      15 sb.player_season_stats(competition_id=55, season_id=43, fmt="dict")
#
# ~/Desktop/statsbombpy-master/statsbombpy/sb.py in player_match_stats(match_id, fmt, creds)
#     204         player_match_stats = api_client.player_match_stats(match_id, creds=creds)
#     205     else:
# --> 206         raise Exception(
#     207             "There is currently no open data for aggregated stats, please provide credentials"
#     208         )
#
# Exception: There is currently no open data for aggregated stats, please provide credentials
